# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\sneha'

# %%
import os
os.chdir(r"C:\Users\sneha\Downloads")
print(os.getcwd())
# Out:
# C:\Users\sneha\Downloads

# %%
df=pd.read_csv("Netflix Content Strategy Analysis.csv")
df.head()
df.isnull().sum()
# Out:
# Title                      0
# Available Globally?        0
# Release Date           16646
# Hours Viewed               0
# Language Indicator         0
# Content Type               0
# dtype: int64
