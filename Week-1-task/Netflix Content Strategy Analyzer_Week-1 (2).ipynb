# %%
# %pip install numpy

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: numpy in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# %pip install matplotlib
# %pip install seaborn
# %pip install plotly
# %pip install missingno

# Importing libs
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AffinityPropagation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import plotly as py
import plotly.graph_objs as go
import os
py.offline.init_notebook_mode(connected = True)
#print(os.listdir("../input"))
import datetime as dt
import missingno as msno
plt.rcParams['figure.dpi'] = 140
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: plotly in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (6.5.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: missingno in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from missingno) (2.4.2)
# Requirement already satisfied: matplotlib in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from missingno) (3.10.8)
# Requirement already satisfied: scipy in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from missingno) (1.17.0)
# Requirement already satisfied: seaborn in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (26.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from seaborn->missingno) (3.0.0)
# Requirement already satisfied: tzdata in c:\Users\jayar\Downloads\project\.venv\Lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.3)
# Note: you may need to restart the kernel to use updated packages.
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.1.min"</script>

# %%
import pandas as pd
import io

url = 'C:\\Users\\jayar\\Downloads\\project\\infosys\\netflix_titles (1).csv'
response = requests.get(url)
response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

# Decode content and load into DataFrame
content = response.content.decode('utf-8')
df = pd.read_csv(io.StringIO(content))
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 import io
#       4 url = 'C:\\Users\\jayar\\Downloads\\project\\infosys\\netflix_titles (1).csv'
# ----> 5 response = requests.get(url)
#       6 response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)
#       8 # Decode content and load into DataFrame
#
# NameError: name 'requests' is not defined

# %%
# Missing data

for i in df.columns:
    null_rate = df[i].isna().sum() / len(df) * 100
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 29.91%
# cast null rate: 9.37%
# country null rate: 9.44%
# date_added null rate: 0.11%
# rating null rate: 0.05%
# duration null rate: 0.03%

# %%
# Replacments

df['country'] = df['country'].fillna(df['country'].mode()[0])


df['cast'].replace(np.nan, 'No Data',inplace  = True)
df['director'].replace(np.nan, 'No Data',inplace  = True)

# Drops

df.dropna(inplace=True)

# Drop Duplicates

df.drop_duplicates(inplace= True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   cast          8790 non-null   object
#  5   country       8790 non-null   object
#  6   date_added    8790 non-null   object
#  7   release_year  8790 non-null   int64
#  8   rating        8790 non-null   object
#  9   duration      8790 non-null   object
#  10  listed_in     8790 non-null   object
#  11  description   8790 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 892.7+ KB

# %%
df["date_added"] = pd.to_datetime(df['date_added'], format='mixed')

df['month_added']=df['date_added'].dt.month
df['month_name_added']=df['date_added'].dt.month_name()
df['year_added'] = df['date_added'].dt.year

df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          No Data
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  month_added  \
# 0  As her father nears the end of his life, filmm...            9
# 1  After crossing paths at a party, a Cape Town t...            9
# 2  To protect his family from a powerful drug lor...            9
#
#   month_name_added  year_added
# 0        September        2021
# 1        September        2021
# 2        September        2021
